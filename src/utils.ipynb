# %%
import pandas as pd
input_path_descr = '/Users/thebekhruz/Desktop/100Days-Of-Code/100-Days-of-NLP-Odyssey/data/intermediate/preprocessing/processed_data_descr.csv'
input_path_tile = '/Users/thebekhruz/Desktop/100Days-Of-Code/100-Days-of-NLP-Odyssey/data/intermediate/preprocessing/processed_data_title.csv'

# %%
df_descr = pd.read_csv(input_path_descr, delimiter='\t', header=None, names=['doc_id', 'type', 'value'])
df_title = pd.read_csv(input_path_tile, delimiter='\t', header=None, names=['doc_id', 'type', 'value'])

df_title.head()
# Out:
#                                  doc_id   type  \
# 0  a7bb9917-95ff-3f55-a640-4c5afcec25f2  title
# 1  c29a7b77-7c46-3b85-88fe-05c8f4b2e384  title
# 2  196c11e6-f7b6-392f-ae41-28653345087c  title
# 3  7a5aace6-2398-3dcf-8843-37ff6ccea875  title
# 4  c66c4715-c03a-3aab-964b-e733f3ff1cf4  title
#
#                                                value
# 0  view southeast junction queen victoria road hi...
# 1  page bucks free press time capsule clock house...
# 2  high wycombe police station queen victoria roa...
# 3  reference library door queen victoria road hig...
# 4  terrace brick flint cottage beech road wycombe...

# %%
combined_df = pd.merge(df_title, df_descr, on='doc_id', suffixes=('_title', '_description'))
# combined_df.head()

# Concatenate the title and description values
combined_df['combined_value'] = combined_df['value_title'] +  ". " + combined_df['value_description']
combined_df.head()
# Out:
#                                  doc_id type_title  \
# 0  a7bb9917-95ff-3f55-a640-4c5afcec25f2      title
# 1  c29a7b77-7c46-3b85-88fe-05c8f4b2e384      title
# 2  196c11e6-f7b6-392f-ae41-28653345087c      title
# 3  7a5aace6-2398-3dcf-8843-37ff6ccea875      title
# 4  c66c4715-c03a-3aab-964b-e733f3ff1cf4      title
#
#                                          value_title type_description  \
# 0  view southeast junction queen victoria road hi...      description
# 1  page bucks free press time capsule clock house...      description
# 2  high wycombe police station queen victoria roa...      description
# 3  reference library door queen victoria road hig...      description
# 4  terrace brick flint cottage beech road wycombe...      description
#
#                                    value_description  \
# 0  east corner queen victoria road junction easto...
# 1  page bucks free press time capsule 7th july 18...
# 2  new police station high wycombe view opposite ...
# ...

# %%
columns_to_drop = ['type_title', 'value_title', 'type_description', 'value_description']
combined_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
combined_df.head()
# Out:
#                                  doc_id  \
# 0  a7bb9917-95ff-3f55-a640-4c5afcec25f2
# 1  c29a7b77-7c46-3b85-88fe-05c8f4b2e384
# 2  196c11e6-f7b6-392f-ae41-28653345087c
# 3  7a5aace6-2398-3dcf-8843-37ff6ccea875
# 4  c66c4715-c03a-3aab-964b-e733f3ff1cf4
#
#                                       combined_value
# 0  view southeast junction queen victoria road hi...
# 1  page bucks free press time capsule clock house...
# 2  high wycombe police station queen victoria roa...
# 3  reference library door queen victoria road hig...
# 4  terrace brick flint cottage beech road wycombe...

# %%
output_file_path = '/Users/thebekhruz/Desktop/100Days-Of-Code/100-Days-of-NLP-Odyssey/data/intermediate/preprocessing/combined_df_for_lda.csv'
combined_df.to_csv(output_file_path, sep='\t', index=False, header=None)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Input In [6], in <module>
#       1 output_file_path = '/Users/thebekhruz/Desktop/100Days-Of-Code/100-Days-of-NLP-Odyssey/data/intermediate/preprocessing'
# ----> 2 combined_df.to_csv(output_file_path, sep='\t', index=False, header=None)
#
# File ~/Desktop/100Days-Of-Code/100-Days-of-NLP-Odyssey/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
